# %% [markdown]
# # Classical Machine Learning

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA

from sklearn.feature_selection import VarianceThreshold
from sklearn.feature_selection import SelectFromModel

import lightgbm as lgbm
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-18-43dda5e01b82> in <module>
#      10 from sklearn.model_selection import GridSearchCV
#      11 from sklearn.model_selection import train_test_split
# ---> 12 from xgboost import XGBClassifier
#      13 from sklearn.decomposition import PCA
#      14 from sklearn.manifold import TSNE
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
os.getcwd()
# Out:
# 'C:\\Users\\DELL\\Desktop\\Projects\\Minor\\Music-Genre-Classification-GTZAN-master\\Music-Genre-Classification-GTZAN-master\\Music Genre Classification'

# %%
df=pd.read_csv('train_data.csv')
df_t=pd.read_csv('test_data.csv')
print(df_t.head())
df.head()
# Out:
#    centroid_max  centroid_min  centroid_mean  centroid_std  centroid_kurtosis  \
# 0   5820.641540    261.040213    1489.099451    869.563705           3.616855
# 1   4162.982445    222.777126     910.093663    617.512284           5.668595
# 2   5473.726906    201.631743     846.608476    696.522263          12.843469
# 3   4152.928614    228.475668     533.912001    292.272569          81.652454
# 4   4100.772671    258.071118    1172.629536    719.401491          -0.074815
#
#    centroid_skew   flux_max  flux_min  flux_mean  flux_std  ...  \
# 0       1.591652  14.850361       0.0   1.520827  1.826153  ...
# 1       2.222877  22.074821       0.0   1.542874  2.485558  ...
# 2       3.163414   9.720446       0.0   1.176664  1.500442  ...
# 3       8.014757  18.117476       0.0   0.813941  1.358511  ...
# 4       0.839901  12.749510       0.0   1.239240  1.326141  ...
#
#    mfcc_18_kurtosis  mfcc_18_skew  mfcc_19_max  mfcc_19_min  mfcc_19_mean  \
# 0         -0.221446      0.104325    23.965410   -35.635025     -4.905429
# 1          0.077406      0.106299    17.759281   -23.351051     -2.515744
# 2          0.572607     -0.289233    15.057287   -31.236706     -3.100091
# 3          0.056112     -0.333996    24.751980   -31.090176     -2.261075
# 4          0.290590     -0.157232    35.952366   -34.056828      0.839582
#
#    mfcc_19_std  mfcc_19_kurtosis  mfcc_19_skew       tempo  label
# 0     8.650370         -0.065995     -0.106457  143.554688      0
# 1     6.939608         -0.078383     -0.160989  123.046875      0
# 2     6.177133          0.532322     -0.291725   83.354335      0
# 3     8.531802          1.142015     -0.832392  143.554688      0
# 4     8.720772          0.250107     -0.045674  103.359375      0
#
# [5 rows x 170 columns]
#    centroid_max  centroid_min  centroid_mean  centroid_std  centroid_kurtosis  \
# 0   4053.985673    925.934083    1727.645355    376.901924           6.096711
# 1   5430.122461    372.728961    1450.533158    615.185827           4.766277
# 2   4709.894987    356.735645    1493.679993    419.421447          11.343314
# 3   3692.033659    261.951363     996.753301    428.061426           2.700672
# 4   4484.855104    783.165978    1749.555484    599.338500           1.670321
#
#    centroid_skew   flux_max  flux_min  flux_mean  flux_std  ...  \
# 0       1.660034  10.981944       0.0   1.391008  1.481524  ...
# 1       1.475144  17.791128       0.0   1.444008  1.996799  ...
# 2       1.900807  14.719387       0.0   1.638258  1.950675  ...
# 3       1.111419  14.619911       0.0   1.247379  1.750351  ...
# 4       1.118021  12.954987       0.0   1.644384  1.958142  ...
#
#    mfcc_18_kurtosis  mfcc_18_skew  mfcc_19_max  mfcc_19_min  mfcc_19_mean  \
# 0          0.954234      0.303920    34.931175   -25.915401      1.033782
# 1          1.002932      0.247480    31.484390   -20.805553      0.305457
# 2          0.347786      0.555627    19.085352   -29.447058     -2.110433
# 3          0.096114     -0.088479    24.258467   -23.636009     -1.658467
# 4          0.617877      0.049771    11.389920   -41.104294    -11.026450
#
#    mfcc_19_std  mfcc_19_kurtosis  mfcc_19_skew       tempo  label
# 0     7.581626          0.408693      0.241352  123.046875      0
# 1     7.547182          0.618586      0.401443  107.666016      0
# 2     6.445112          0.502269     -0.048041  161.499023      0
# 3     6.555074          0.942891      0.145058  172.265625      0
# 4     8.213293          0.469296     -0.549097  135.999178      0
#
# [5 rows x 170 columns]

# %%
X_train=df.drop('label',axis=1).values
y_train=df['label'].values
print(X_train.shape)
print(y_train.shape)
X_test=df_t.drop('label',axis=1).values
y_test=df_t['label'].values
print(X_test.shape)
print(y_test.shape)
# Out:
# (900, 169)
# (900,)
# (100, 169)
# (100,)

# %%
#X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y,random_state=42)

# %% [markdown]
# ## Support Vector Machines

# %%
params = {
    "cls__C": [0.5, 1, 5, 10],
    "cls__kernel": ['rbf', 'sigmoid','poly'],
}

pipe_svm = Pipeline([
    ('scale', StandardScaler()),
    ('var_tresh', VarianceThreshold(threshold=0.1)),
    ('feature_selection', SelectFromModel(lgbm.LGBMClassifier())),
    ('cls', SVC())
])

grid_svm = GridSearchCV(pipe_svm, params, scoring='accuracy', n_jobs=-1, cv=9,verbose=2)
grid_svm.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-79b8e9c61e44> in <module>
#       6 pipe_svm = Pipeline([
#       7     ('scale', StandardScaler()),
# ----> 8     ('var_tresh', VarianceThreshold(threshold=0.1)),
#       9     ('feature_selection', SelectFromModel(lgbm.LGBMClassifier())),
#      10     ('cls', SVC())
#
# NameError: name 'VarianceThreshold' is not defined

# %%
preds = grid_svm.predict(X_test)
print("Best score on validation set (accuracy) = {:.4f}".format(grid_svm.best_score_))
print("Best score on test set (accuracy) = {:.4f}".format(accuracy_score(y_test, preds)))
# Out:
# Best score on validation set (accuracy) = 0.7111
# Best score on test set (accuracy) = 0.7200

# %%
from sklearn.externals import joblib

joblib.dump(grid_svm, "models/pipe_svm.joblib")
# Out:
# ['models/pipe_svm.joblib']

# %% [markdown]
# ## Xtreme Gradient Boost -XGB-

# %%
params = {
    "cls__max_depth": [4, 6, 10, 20],
    'cls__booster':['gbtree','dart']
}

pipe_xbg = Pipeline([
    ('var_tresh', VarianceThreshold(threshold=0.1)),
    ('cls', XGBClassifier(objective='multi:softmax',num_class=10,verbosity=1))
])

grid_xgb = GridSearchCV(pipe_xbg, params, scoring='accuracy', n_jobs=-1, cv=3)
grid_xgb.fit(X_train, y_train)
# Out:
# [10:08:58] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:58] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:58] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:58] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:58] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:58] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 26 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:58] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 22 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:58] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:58] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:58] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 26 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:58] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:58] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:58] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:58] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 28 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:58] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 22 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:58] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 30 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:58] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:58] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 26 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:58] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:58] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 22 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 26 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 26 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 22 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 22 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 22 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 30 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 26 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 26 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 26 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 22 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 26 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 26 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 22 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 22 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 28 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 26 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 22 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 26 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 22 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:08:59] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 28 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 26 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 22 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 22 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 26 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 22 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 22 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:00] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:01] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:01] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:01] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:01] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:01] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:01] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 26 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:01] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 26 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:01] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:01] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:01] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:01] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:01] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 26 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:01] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:01] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:01] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:01] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:01] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 22 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:01] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:01] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:01] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:01] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:01] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 26 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:01] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:01] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:01] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:01] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:01] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:01] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:01] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 10 extra nodes, 0 pruned nodes, max_depth=3
# [10:09:01] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:01] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 22 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:01] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:01] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:01] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:01] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:01] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:01] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 26 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:01] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 10 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 22 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=3
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 22 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 10 extra nodes, 0 pruned nodes, max_depth=3
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 22 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 26 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 10 extra nodes, 0 pruned nodes, max_depth=3
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:02] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:03] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:03] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:03] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:03] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 22 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:03] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:03] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:03] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 10 extra nodes, 0 pruned nodes, max_depth=3
# [10:09:03] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:03] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:03] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:03] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:03] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:03] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:03] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:03] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:03] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:03] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [10:09:03] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:03] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:03] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:03] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:03] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:03] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:03] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:03] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:03] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:03] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 8 extra nodes, 0 pruned nodes, max_depth=3
# [10:09:03] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:03] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:03] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:03] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:03] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:03] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:03] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:03] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:03] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:04] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 8 extra nodes, 0 pruned nodes, max_depth=3
# [10:09:04] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:04] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:04] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:04] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:04] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:04] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:04] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:04] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:04] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:04] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [10:09:04] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:04] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:04] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:04] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:04] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 10 extra nodes, 0 pruned nodes, max_depth=3
# [10:09:04] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:04] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:04] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 24 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:04] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:04] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [10:09:04] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:04] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 20 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:04] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:04] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:04] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:04] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=3
# [10:09:04] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:04] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:04] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:04] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [10:09:04] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:04] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:04] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:04] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:04] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 8 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:04] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 12 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:04] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 16 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:04] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 18 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:04] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 14 extra nodes, 0 pruned nodes, max_depth=4
# [10:09:04] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# ...
# [10:09:11] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:11] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:11] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 8 extra nodes, 0 pruned nodes, max_depth=3
# [10:09:11] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:11] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [10:09:11] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# [10:09:11] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:11] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# [10:09:11] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:11] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:11] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:11] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:11] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [10:09:11] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:11] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [10:09:11] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# [10:09:11] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# [10:09:11] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:11] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:11] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:11] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:11] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:11] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [10:09:11] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:11] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=3
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 0 extra nodes, 0 pruned nodes, max_depth=0
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 2 extra nodes, 0 pruned nodes, max_depth=1
# [10:09:12] INFO: C:\Users\Administrator\workspace\xgboost-win64_release_1.0.0\src\tree\updater_prune.cc:89: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# GridSearchCV(cv=3, error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('var_tresh',
#                                         VarianceThreshold(threshold=0.1)),
#                                        ('cls',
#                                         XGBClassifier(base_score=None,
#                                                       booster=None,
#                                                       colsample_bylevel=None,
#                                                       colsample_bynode=None,
#                                                       colsample_bytree=None,
#                                                       gamma=None, gpu_id=None,
#                                                       importance_type='gain',
#                                                       interaction_constraints=None,
#                                                       learning_rate=None,
#                                                       max_delta_step=None,...
#                                                       random_state=None,
#                                                       reg_alpha=None,
#                                                       reg_lambda=None,
#                                                       scale_pos_weight=None,
#                                                       subsample=None,
#                                                       tree_method=None,
#                                                       validate_parameters=False,
#                                                       verbosity=2))],
#                                 verbose=False),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'cls__booster': ['gbtree', 'dart'],
#                          'cls__max_depth': [4, 6, 10, 20]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='accuracy', verbose=0)

# %%
preds1 = grid_xgb.predict(X_test)
print("Best score on validation set (accuracy) = {:.4f}".format(grid_xgb.best_score_))
print("Best score on test set (accuracy) = {:.4f}".format(accuracy_score(y_test, preds1)))
# Out:
# Best score on validation set (accuracy) = 0.5678
# Best score on test set (accuracy) = 0.6900

# %%
joblib.dump(grid_xgb, "models/pipe_xgb.joblib")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-15ea45655048> in <module>
# ----> 1 joblib.dump(grid_xgb, "models/pipe_xgb.joblib")
#       2
#
# NameError: name 'joblib' is not defined

# %% [markdown]
# ## Deep Neural Network

# %%
import keras
from keras.models import Sequential
from keras.utils import to_categorical
from keras.layers import Dense,Dropout,Input
from keras.callbacks import ReduceLROnPlateau,EarlyStopping
from keras.models import Model
from keras.activations import relu
from keras.callbacks import History 
from keras.utils.vis_utils import plot_model
from keras.optimizers import Adam
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-30-3aea1c11a5b0> in <module>
# ----> 1 import keras
#       2 from keras.models import Sequential
#       3 from keras.utils import to_categorical
#       4 from keras.layers import Dense,Dropout,Input
#       5 from keras.callbacks import ReduceLROnPlateau,EarlyStopping
#
# ModuleNotFoundError: No module named 'keras'

# %%
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.fit_transform(X_test)
input_shape=X_train.shape[1]
y_train_nn=to_categorical(y_train,10,'int')
y_train_nn[:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-9a22d8f6b0aa> in <module>
#       3 X_test=sc.fit_transform(X_test)
#       4 input_shape=X_train.shape[1]
# ----> 5 y_train_nn=to_categorical(y_train,10,'int')
#       6 y_train_nn[:5]
#
# NameError: name 'to_categorical' is not defined

# %%
hist = History()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-0700b9ff8a5b> in <module>
# ----> 1 hist = History()
#
# NameError: name 'History' is not defined

# %%
inp=Input(shape=(input_shape,))
model = Dense(500,activation='relu')(inp)
model = Dropout(0.3)(model)
model = Dense(8000,activation='relu')(model)
model = Dropout(0.2)(model)
model = Dense(4000,activation='relu')(model)
model = Dropout(0.2)(model)
model = Dense(2000,activation='relu')(model)
model = Dropout(0.2)(model)
model = Dense(1000,activation='relu')(model)
model = Dense(500,activation='relu')(model)
model = Dense(10,activation='softmax')(model)

model = Model(inputs=inp,outputs=model)
model.compile(optimizer='adam', 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])
lr=ReduceLROnPlateau(monitor='val_loss',factor=0.5,patience=3,verbose=1)
es=EarlyStopping(monitor='val_loss',patience=20,verbose=1)
#plot_model(model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-c908d1ed1094> in <module>
# ----> 1 inp=Input(shape=(input_shape,))
#       2 model = Dense(500,activation='relu')(inp)
#       3 model = Dropout(0.3)(model)
#       4 model = Dense(8000,activation='relu')(model)
#       5 model = Dropout(0.2)(model)
#
# NameError: name 'Input' is not defined

# %%
model.fit(X_train, y_train_nn, epochs = 120, validation_split = .055, callbacks = [hist,lr,es])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-94ece2e3cb88> in <module>
# ----> 1 model.fit(X_train, y_train_nn, epochs = 120, validation_split = .055, callbacks = [hist,lr,es])
#
# NameError: name 'model' is not defined

# %%
y_pred =  model.predict(X_test)
y_pred = np.round(y_pred[:,1])
print(accuracy_score(y_pred,y_test))

plt.plot(hist.history['accuracy'], color = 'red')
plt.plot(hist.history['val_accuracy'], color = 'blue')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-be9f852b76e4> in <module>
# ----> 1 y_pred =  model.predict(X_test)
#       2 y_pred = np.round(y_pred[:,1])
#       3 print(accuracy_score(y_pred,y_test))
#       4
#       5 plt.plot(hist.history['accuracy'], color = 'red')
#
# NameError: name 'model' is not defined
